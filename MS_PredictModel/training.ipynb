# %% [markdown]
# # Training program for Experiment

# %% [markdown]
# ## setting path

# %%
import sys
import os
from datetime import datetime

sys.path.append(os.path.split(os.getcwd())[0])

def get_timef():
    now = datetime.now()
    return now.strftime("%Y%m%d-%H%M")

print(get_timef())
# Out:
# 20190902-1641

# %% [markdown]
# # Vocab,datasetのロード

# %%
from fast_jtnn import *
from MS_PredictModel import MS_Dataset,MS_Dataset_pickle,dataset_load
import pickle
import torch

VOCAB_FILE = "./MS_vocab.txt"

vocab = [x.strip("\r\n ") for x in open(VOCAB_FILE,"r")]
vocab = Vocab(vocab)

'''
MS_Dataset.QUERY = """select smiles,file_path from massbank where ms_type="MS" and instrument_type="EI-B" and smiles<>'N/A';"""
dataset = MS_Dataset(vocab=vocab,host="localhost",database="chemoinfo",batch_size=20)
'''
train_vali_rate = 0.9

train_dataset, vali_dataset = dataset_load("./massbank.pkl",vocab,20,train_vali_rate)
print("number of train dataset :",len(train_dataset))
print("number of validation dataset :",len(vali_dataset))
# Out:
# ('number of train dataset :', 6584)
# ('number of validation dataset :', 732)

# %% [markdown]
# ## モデルの作成

# %%
from ms_encoder import ms_peak_encoder,ms_peak_encoder_lstm,ms_peak_encoder_cnn
import torch.nn as nn
import torch
hidden_size = 100
latent_size = 56
depthT = 20
depthG = 3

dec_model = JTNNVAE(vocab, hidden_size, latent_size, depthT, depthG).to('cuda')
print dec_model
#enc_model = ms_peak_encoder_lstm(train_dataset.max_spectrum_size,output_size=latent_size,\
#        hidden_size=200,embedding_size=20,num_rnn_layers=2,bidirectional=False,dropout_rate=0.5).to('cuda')
enc_model = ms_peak_encoder_cnn(train_dataset.max_spectrum_size,output_size=latent_size,\
                                 conv1_channel=64,conv2_channel=128,conv_output_channel=256,\
                                 kernel1_width=5,kernel2_width=5,conv_output_width=5,\
                                 hidden_size=200,embedding_size=10,num_rnn_layers=2,bidirectional=False,dropout_rate=0.2).to('cuda')
print enc_model

for param in dec_model.parameters():
    if param.dim() == 1:
        nn.init.constant_(param, 0)
    else:
        nn.init.xavier_normal_(param)
load_model = "./vae_model/model.iter-50000"
dec_model.load_state_dict(torch.load(load_model,map_location='cuda'))

print "Model #Params: %dK" % (sum([x.nelement() for x in dec_model.parameters()]) / 1000,)
print "Model #Params: %dK" % (sum([x.nelement() for x in enc_model.parameters()]) / 1000,)
# Out:
# /home/kusachi/anaconda3/envs/jtvae/lib/python2.7/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# JTNNVAE(
#   (jtnn): JTNNEncoder(
#     (embedding): Embedding(1027, 100)
#     (outputNN): Sequential(
#       (0): Linear(in_features=200, out_features=100, bias=True)
#       (1): ReLU()
#     )
#     (GRU): GraphGRU(
#       (W_z): Linear(in_features=200, out_features=100, bias=True)
#       (W_r): Linear(in_features=100, out_features=100, bias=False)
#       (U_r): Linear(in_features=100, out_features=100, bias=True)
#       (W_h): Linear(in_features=200, out_features=100, bias=True)
#     )
#   )
#   (decoder): JTNNDecoder(
#     (embedding): Embedding(1027, 100)
#     (W_z): Linear(in_features=200, out_features=100, bias=True)
#     (U_r): Linear(in_features=100, out_features=100, bias=False)
#     (W_r): Linear(in_features=100, out_features=100, bias=True)
#     (W_h): Linear(in_features=200, out_features=100, bias=True)
#     (W): Linear(in_features=128, out_features=100, bias=True)
#     (U): Linear(in_features=128, out_features=100, bias=True)
#     (U_i): Linear(in_features=200, out_features=100, bias=True)
#     (W_o): Linear(in_features=100, out_features=1027, bias=True)
#     (U_o): Linear(in_features=100, out_features=1, bias=True)
#     (pred_loss): CrossEntropyLoss()
#     (stop_loss): BCEWithLogitsLoss()
#   )
#   (jtmpn): JTMPN(
#     (W_i): Linear(in_features=47, out_features=100, bias=False)
#     (W_h): Linear(in_features=100, out_features=100, bias=False)
#     (W_o): Linear(in_features=142, out_features=100, bias=True)
#   )
#   (mpn): MPN(
#     (W_i): Linear(in_features=57, out_features=100, bias=False)
#     (W_h): Linear(in_features=100, out_features=100, bias=False)
#     (W_o): Linear(in_features=146, out_features=100, bias=True)
#   )
#   (A_assm): Linear(in_features=28, out_features=100, bias=False)
#   (assm_loss): CrossEntropyLoss()
#   (T_mean): Linear(in_features=100, out_features=28, bias=True)
#   (T_var): Linear(in_features=100, out_features=28, bias=True)
#   (G_mean): Linear(in_features=100, out_features=28, bias=True)
#   (G_var): Linear(in_features=100, out_features=28, bias=True)
# )
# ms_peak_encoder_cnn(
#   (embedding): Embedding(1000, 10)
#   (convSequential): Sequential(
#     (0): Conv1d(11, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Conv1d(64, 64, kernel_size=(5,), stride=(1,), padding=(2,))
#     (5): LeakyReLU(negative_slope=0.01)
#   )
#   (rnn): GRU(64, 200, num_layers=2, batch_first=True)
#   (T_mean): Linear(in_features=200, out_features=28, bias=True)
#   (T_var): Linear(in_features=200, out_features=28, bias=True)
#   (G_mean): Linear(in_features=200, out_features=28, bias=True)
#   (G_var): Linear(in_features=200, out_features=28, bias=True)
#   (output): Linear(in_features=56, out_features=56, bias=True)
# )
# Model #Params: 569K
# Model #Params: 481K

# %% [markdown]
# ## setting optimizer

# %%
import torch.optim as optim
import torch.optim.lr_scheduler as lr_scheduler

enc_optimizer = optim.Adam(enc_model.parameters(), lr=1e-3)
dec_optimizer = optim.Adam(dec_model.parameters(), lr=1e-3)
#optimizer = optim.SGD(enc_model.parameters(),lr=100)
enc_scheduler = lr_scheduler.ExponentialLR(enc_optimizer, 0.9)
dec_scheduler = lr_scheduler.ExponentialLR(dec_optimizer, 0.9)
#scheduler.step()

# %%
from MS_PredictModel import ms_peak_encoder,MS_Dataset
from torch.autograd import Variable
from tqdm import tqdm
import numpy as np

pbar = None
train_dataset.batch_size = 20
vali_dataset.batch_size = 10

anneal_iter = 7400

word_rate=1.0
topo_rate=1.0
assm_rate=1.0

beta = 0
step_beta = 0.002
kl_anneal_iter = 10 # epoch
max_beta = 1
warmup = 50 # epoch

fine_tunning_warmup=30 # epoch

def training(max_epoch = 100):
    global pbar
    global beta
    total_step = 0
    meters = np.zeros(7)
    vali_meters = np.zeros(6)
    with open("log2.csv","w") as f:
        f.write("epoch,iter.,kl_loss,word,topo,assm,wors_loss,topo_loss,assm_loss,vali word,vali topo,vali assm,vali_word_loss,vali_topo_loss,vali_assm_loss\n")
    for epoch in range(max_epoch):
        if epoch % kl_anneal_iter == 0 and epoch >= warmup:
            beta = min(max_beta, beta + step_beta)
        print("epoch : ",epoch)
        for batch in train_dataset:
            x_batch, x_jtenc_holder, x_mpn_holder, x_jtmpn_holder,x,y = batch
            total_step+=1
            #pbar.update(1)
            x = x.to('cuda')
            y = y.to('cuda')
            
            enc_model.zero_grad()
            dec_model.zero_grad()
            enc_optimizer.zero_grad()
            dec_optimizer.zero_grad()
            
            h,kl_loss = enc_model(x,y,training=True,sample=True)
            tree_vec = h[:,:h.shape[1]/2]
            mol_vec  = h[:,h.shape[1]/2:]
            _, x_tree_mess = dec_model.jtnn(*x_jtenc_holder)
            word_loss, topo_loss, word_acc, topo_acc = dec_model.decoder(x_batch,tree_vec)
            assm_loss, assm_acc = dec_model.assm(x_batch, x_jtmpn_holder, mol_vec , x_tree_mess)
            total_loss = word_loss*word_rate+\
                         topo_loss*topo_rate+\
                         assm_loss*assm_rate+\
                         kl_loss*beta
            total_loss.backward()
            enc_optimizer.step()
            if epoch >= fine_tunning_warmup:
                dec_optimizer.step()
            
            del x,y,h

            meters = meters + np.array([kl_loss.item(),word_acc * 100, topo_acc * 100, assm_acc * 100,word_loss.item(),topo_loss.item(),assm_loss.item()])
            if total_step % 200 == 0:
                vali_total = 0
                for batch in vali_dataset:
                    x_batch, x_jtenc_holder, x_mpn_holder, x_jtmpn_holder,x,y = batch
                    x = x.to('cuda')
                    y = y.to('cuda')
                    with torch.no_grad():
                        h,_ = enc_model(x,y,training=False,sample=False)
                        tree_vec = h[:,:h.shape[1]/2]
                        mol_vec  = h[:,h.shape[1]/2:]
                        _, x_tree_mess = dec_model.jtnn(*x_jtenc_holder)
                        word_loss, topo_loss, word_acc, topo_acc = dec_model.decoder(x_batch,tree_vec)
                        assm_loss, assm_acc = dec_model.assm(x_batch, x_jtmpn_holder, mol_vec , x_tree_mess)
                        vali_meters = vali_meters + np.array([word_acc * 100, topo_acc * 100, assm_acc * 100,word_loss.item(),topo_loss.item(),assm_loss.item()])
                        vali_total += 1    
                    del x,y,h
                    
                meters /= 200
                vali_meters /= vali_total
                print "[%d] , kl_loss %.2f, Word: %.2f, Topo: %.2f, Assm: %.2f vali_Word: %.2f, vali_Topo: %.2f, vali_assm: %.2f, learning rate: %.4f" % \
                    (total_step, meters[0], meters[1], meters[2],meters[3], vali_meters[0],vali_meters[1],vali_meters[2],enc_scheduler.get_lr()[0])                
                with open("log2.csv","a") as f:
                    f.write("%d,%d," % (epoch,total_step))
                    f.write("%.2f,%.2f,%.2f,%.2f,%.2f,%.2f,%.2f," % (meters[0], meters[1], meters[2],meters[3],meters[4],meters[5],meters[6]))
                    f.write("%.2f,%.2f,%.2f,%.2f,%.2f,%.2f\n" % (vali_meters[0],vali_meters[1],vali_meters[2],vali_meters[3],vali_meters[4],vali_meters[5]))
                sys.stdout.flush()
                meters *= 0
                vali_meters *= 0
            if total_step % 200 == 0:
                torch.save(enc_model.state_dict(), "./enc_model" + "/model.iter-" + str(total_step))
                torch.save(dec_model.state_dict(), "./dec_model" + "/model.iter-" + str(total_step))
            #if total_step % anneal_iter == 0:
                #scheduler.step()

#import pdb; pdb.set_trace()
try:
    #if pbar is None:
        #pbar = tqdm()
    if not os.path.exists("./enc_model"):
        os.mkdir("./enc_model")
    if not os.path.exists("./dec_model"):
        os.mkdir("./dec_model")
    training(200)
except RuntimeError as e:
    #if pbar is not None:
        #del pbar
    import traceback
    print(traceback.format_exc())
    #import pdb; pdb.set_trace()
    print(e)
# Out:
# ('epoch : ', 0)
# (torch.Size([20, 310, 10]),)
# (torch.Size([20, 310, 1]),)
# (torch.Size([20, 310, 11]),)
# (torch.Size([20, 310, 64]),)
# (torch.Size([20, 310, 64]),)
# (torch.Size([20, 310, 200]),)
# (torch.Size([20, 200]),)
# /home/kusachi/anaconda3/envs/jtvae/lib/python2.7/site-packages/torch/nn/functional.py:1386: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# /home/kusachi/anaconda3/envs/jtvae/lib/python2.7/site-packages/torch/nn/functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# [200] , kl_loss 434.00, Word: 34.00, Topo: 85.56, Assm: 83.03 vali_Word: 36.19, vali_Topo: 85.97, vali_assm: 84.42, learning rate: 0.0010
# ('epoch : ', 1)
# [400] , kl_loss 640.46, Word: 35.01, Topo: 85.80, Assm: 84.48 vali_Word: 36.98, vali_Topo: 85.50, vali_assm: 82.29, learning rate: 0.0010
# [600] , kl_loss 611.64, Word: 36.28, Topo: 86.00, Assm: 84.54 vali_Word: 38.51, vali_Topo: 86.01, vali_assm: 84.79, learning rate: 0.0010
# ('epoch : ', 2)
# [800] , kl_loss 548.46, Word: 37.72, Topo: 86.18, Assm: 85.43 vali_Word: 40.58, vali_Topo: 85.81, vali_assm: 83.63, learning rate: 0.0010
# ('epoch : ', 3)
# [1000] , kl_loss 529.48, Word: 38.50, Topo: 86.27, Assm: 84.19 vali_Word: 41.99, vali_Topo: 86.21, vali_assm: 83.57, learning rate: 0.0010
# [1200] , kl_loss 506.20, Word: 40.65, Topo: 86.41, Assm: 85.02 vali_Word: 40.77, vali_Topo: 85.81, vali_assm: 83.35, learning rate: 0.0010
# ('epoch : ', 4)
# [1400] , kl_loss 480.51, Word: 42.39, Topo: 86.79, Assm: 84.90 vali_Word: 45.08, vali_Topo: 86.34, vali_assm: 83.99, learning rate: 0.0010
# [1600] , kl_loss 466.36, Word: 43.60, Topo: 86.53, Assm: 85.02 vali_Word: 45.31, vali_Topo: 86.49, vali_assm: 85.97, learning rate: 0.0010
# ('epoch : ', 5)
# [1800] , kl_loss 443.51, Word: 44.70, Topo: 86.91, Assm: 85.38 vali_Word: 46.30, vali_Topo: 86.56, vali_assm: 84.36, learning rate: 0.0010
# ('epoch : ', 6)
# [2000] , kl_loss 434.42, Word: 44.83, Topo: 86.63, Assm: 84.64 vali_Word: 42.88, vali_Topo: 86.90, vali_assm: 84.78, learning rate: 0.0010
# [2200] , kl_loss 432.34, Word: 46.16, Topo: 87.05, Assm: 85.95 vali_Word: 46.57, vali_Topo: 86.85, vali_assm: 85.73, learning rate: 0.0010
# ('epoch : ', 7)
# [2400] , kl_loss 418.46, Word: 46.27, Topo: 87.06, Assm: 85.67 vali_Word: 47.81, vali_Topo: 86.72, vali_assm: 85.13, learning rate: 0.0010
# [2600] , kl_loss 407.84, Word: 46.49, Topo: 87.08, Assm: 84.97 vali_Word: 45.53, vali_Topo: 86.62, vali_assm: 85.67, learning rate: 0.0010
# ('epoch : ', 8)
# [2800] , kl_loss 406.73, Word: 47.39, Topo: 87.21, Assm: 86.03 vali_Word: 43.72, vali_Topo: 87.13, vali_assm: 84.97, learning rate: 0.0010
# ('epoch : ', 9)
# [3000] , kl_loss 404.78, Word: 47.51, Topo: 87.14, Assm: 85.69 vali_Word: 46.40, vali_Topo: 87.22, vali_assm: 84.32, learning rate: 0.0010
# [3200] , kl_loss 397.18, Word: 47.67, Topo: 87.41, Assm: 85.31 vali_Word: 46.71, vali_Topo: 87.37, vali_assm: 85.30, learning rate: 0.0010
# ('epoch : ', 10)
# [3400] , kl_loss 391.83, Word: 47.97, Topo: 87.30, Assm: 84.62 vali_Word: 49.74, vali_Topo: 87.28, vali_assm: 85.74, learning rate: 0.0010
# [3600] , kl_loss 388.03, Word: 48.05, Topo: 87.66, Assm: 85.90 vali_Word: 48.24, vali_Topo: 87.26, vali_assm: 84.65, learning rate: 0.0010
# ('epoch : ', 11)
# [3800] , kl_loss 378.53, Word: 49.10, Topo: 87.39, Assm: 85.28 vali_Word: 47.64, vali_Topo: 87.39, vali_assm: 84.12, learning rate: 0.0010
# ('epoch : ', 12)
# [4000] , kl_loss 379.69, Word: 48.65, Topo: 87.66, Assm: 85.94 vali_Word: 48.60, vali_Topo: 86.81, vali_assm: 85.64, learning rate: 0.0010
# [4200] , kl_loss 375.96, Word: 49.59, Topo: 87.61, Assm: 85.25 vali_Word: 49.06, vali_Topo: 87.76, vali_assm: 84.68, learning rate: 0.0010
# ('epoch : ', 13)
# [4400] , kl_loss 382.72, Word: 49.70, Topo: 87.69, Assm: 85.73 vali_Word: 49.61, vali_Topo: 87.56, vali_assm: 84.77, learning rate: 0.0010
# [4600] , kl_loss 378.02, Word: 49.91, Topo: 87.94, Assm: 86.16 vali_Word: 50.26, vali_Topo: 87.48, vali_assm: 84.32, learning rate: 0.0010
# ('epoch : ', 14)
# [4800] , kl_loss 373.87, Word: 50.39, Topo: 87.85, Assm: 86.15 vali_Word: 48.50, vali_Topo: 87.89, vali_assm: 85.95, learning rate: 0.0010
# ('epoch : ', 15)
# [5000] , kl_loss 368.57, Word: 50.51, Topo: 87.97, Assm: 85.70 vali_Word: 49.73, vali_Topo: 87.65, vali_assm: 85.47, learning rate: 0.0010
# [5200] , kl_loss 368.07, Word: 50.81, Topo: 88.07, Assm: 86.22 vali_Word: 49.83, vali_Topo: 87.81, vali_assm: 84.21, learning rate: 0.0010
# ('epoch : ', 16)
# [5400] , kl_loss 369.66, Word: 51.30, Topo: 87.96, Assm: 85.90 vali_Word: 50.87, vali_Topo: 87.75, vali_assm: 85.90, learning rate: 0.0010
# ('epoch : ', 17)
# [5600] , kl_loss 361.13, Word: 51.18, Topo: 88.10, Assm: 85.77 vali_Word: 50.76, vali_Topo: 88.04, vali_assm: 86.13, learning rate: 0.0010
# [5800] , kl_loss 364.85, Word: 51.82, Topo: 88.03, Assm: 85.89 vali_Word: 50.26, vali_Topo: 87.64, vali_assm: 84.74, learning rate: 0.0010
# ('epoch : ', 18)
# [6000] , kl_loss 367.11, Word: 51.96, Topo: 88.31, Assm: 86.81 vali_Word: 49.99, vali_Topo: 87.82, vali_assm: 85.45, learning rate: 0.0010
# [6200] , kl_loss 364.25, Word: 51.39, Topo: 88.00, Assm: 85.47 vali_Word: 50.97, vali_Topo: 87.72, vali_assm: 85.76, learning rate: 0.0010
# ('epoch : ', 19)
# [6400] , kl_loss 369.52, Word: 52.48, Topo: 88.31, Assm: 86.59 vali_Word: 52.07, vali_Topo: 87.93, vali_assm: 85.27, learning rate: 0.0010
# ('epoch : ', 20)
# [6600] , kl_loss 365.52, Word: 52.54, Topo: 88.14, Assm: 85.90 vali_Word: 51.87, vali_Topo: 87.24, vali_assm: 84.17, learning rate: 0.0010
# [6800] , kl_loss 366.24, Word: 53.35, Topo: 88.40, Assm: 86.66 vali_Word: 51.36, vali_Topo: 87.63, vali_assm: 84.27, learning rate: 0.0010
# ('epoch : ', 21)
# [7000] , kl_loss 363.67, Word: 52.84, Topo: 88.39, Assm: 86.14 vali_Word: 50.96, vali_Topo: 87.92, vali_assm: 85.60, learning rate: 0.0010
# [7200] , kl_loss 365.95, Word: 52.92, Topo: 88.35, Assm: 85.79 vali_Word: 52.49, vali_Topo: 88.32, vali_assm: 85.20, learning rate: 0.0010
# ('epoch : ', 22)
# [7400] , kl_loss 357.71, Word: 53.97, Topo: 88.38, Assm: 86.88 vali_Word: 50.46, vali_Topo: 87.72, vali_assm: 86.35, learning rate: 0.0010
# ('epoch : ', 23)
# [7600] , kl_loss 361.48, Word: 52.98, Topo: 88.45, Assm: 86.30 vali_Word: 52.26, vali_Topo: 88.14, vali_assm: 83.37, learning rate: 0.0010
# [7800] , kl_loss 363.16, Word: 53.89, Topo: 88.55, Assm: 86.47 vali_Word: 51.65, vali_Topo: 87.88, vali_assm: 85.73, learning rate: 0.0010
# ('epoch : ', 24)
# [8000] , kl_loss 364.32, Word: 54.20, Topo: 88.36, Assm: 86.34 vali_Word: 50.74, vali_Topo: 88.13, vali_assm: 84.61, learning rate: 0.0010
# [8200] , kl_loss 360.68, Word: 54.30, Topo: 88.68, Assm: 86.88 vali_Word: 52.08, vali_Topo: 87.76, vali_assm: 86.03, learning rate: 0.0010
# ('epoch : ', 25)
# [8400] , kl_loss 355.60, Word: 54.11, Topo: 88.60, Assm: 86.65 vali_Word: 52.16, vali_Topo: 88.07, vali_assm: 84.02, learning rate: 0.0010
# ('epoch : ', 26)
# [8600] , kl_loss 365.59, Word: 55.04, Topo: 88.51, Assm: 86.27 vali_Word: 51.54, vali_Topo: 88.19, vali_assm: 86.78, learning rate: 0.0010
# [8800] , kl_loss 369.30, Word: 54.76, Topo: 88.65, Assm: 86.24 vali_Word: 51.44, vali_Topo: 88.37, vali_assm: 84.92, learning rate: 0.0010
# ('epoch : ', 27)
# [9000] , kl_loss 372.01, Word: 54.80, Topo: 88.62, Assm: 86.23 vali_Word: 52.82, vali_Topo: 88.06, vali_assm: 85.00, learning rate: 0.0010
# [9200] , kl_loss 374.22, Word: 55.25, Topo: 88.72, Assm: 86.80 vali_Word: 52.92, vali_Topo: 88.29, vali_assm: 85.82, learning rate: 0.0010
# ('epoch : ', 28)
# [9400] , kl_loss 374.65, Word: 55.12, Topo: 88.72, Assm: 86.55 vali_Word: 52.83, vali_Topo: 88.46, vali_assm: 85.14, learning rate: 0.0010
# ('epoch : ', 29)
# [9600] , kl_loss 369.88, Word: 55.82, Topo: 88.82, Assm: 87.03 vali_Word: 51.81, vali_Topo: 88.44, vali_assm: 85.41, learning rate: 0.0010
# [9800] , kl_loss 377.12, Word: 55.79, Topo: 88.60, Assm: 86.68 vali_Word: 51.89, vali_Topo: 88.08, vali_assm: 85.24, learning rate: 0.0010
# ('epoch : ', 30)
# [10000] , kl_loss 369.63, Word: 60.65, Topo: 90.90, Assm: 87.09 vali_Word: 61.77, vali_Topo: 92.61, vali_assm: 85.25, learning rate: 0.0010
# ('epoch : ', 31)
# [10200] , kl_loss 347.35, Word: 66.48, Topo: 93.03, Assm: 87.85 vali_Word: 65.57, vali_Topo: 92.56, vali_assm: 87.22, learning rate: 0.0010
# [10400] , kl_loss 331.38, Word: 68.52, Topo: 93.70, Assm: 89.78 vali_Word: 65.37, vali_Topo: 92.28, vali_assm: 88.03, learning rate: 0.0010
# ('epoch : ', 32)
# [10600] , kl_loss 315.70, Word: 69.38, Topo: 94.44, Assm: 90.55 vali_Word: 66.65, vali_Topo: 93.79, vali_assm: 88.69, learning rate: 0.0010
# [10800] , kl_loss 313.27, Word: 70.28, Topo: 94.39, Assm: 91.19 vali_Word: 66.41, vali_Topo: 93.79, vali_assm: 87.82, learning rate: 0.0010
# ('epoch : ', 33)
# [11000] , kl_loss 306.17, Word: 71.24, Topo: 94.99, Assm: 91.37 vali_Word: 66.87, vali_Topo: 94.22, vali_assm: 88.69, learning rate: 0.0010
# ('epoch : ', 34)
# [11200] , kl_loss 300.67, Word: 70.95, Topo: 95.01, Assm: 91.31 vali_Word: 67.49, vali_Topo: 94.14, vali_assm: 89.24, learning rate: 0.0010
# [11400] , kl_loss 301.98, Word: 72.04, Topo: 95.43, Assm: 92.59 vali_Word: 68.29, vali_Topo: 94.52, vali_assm: 89.25, learning rate: 0.0010
# ('epoch : ', 35)
# [11600] , kl_loss 299.07, Word: 72.28, Topo: 95.62, Assm: 92.38 vali_Word: 67.98, vali_Topo: 94.42, vali_assm: 89.37, learning rate: 0.0010
# [11800] , kl_loss 297.79, Word: 72.08, Topo: 95.41, Assm: 92.22 vali_Word: 67.81, vali_Topo: 94.25, vali_assm: 88.96, learning rate: 0.0010
# ('epoch : ', 36)
# [12000] , kl_loss 293.07, Word: 72.90, Topo: 95.82, Assm: 93.50 vali_Word: 68.27, vali_Topo: 94.57, vali_assm: 88.90, learning rate: 0.0010
# ('epoch : ', 37)
# ('epoch : ', 57)
# [18800] , kl_loss 130.00, Word: 80.42, Topo: 97.88, Assm: 95.81 vali_Word: 70.39, vali_Topo: 95.17, vali_assm: 88.49, learning rate: 0.0010
# [19000] , kl_loss 128.20, Word: 80.76, Topo: 98.02, Assm: 95.87 vali_Word: 70.41, vali_Topo: 94.98, vali_assm: 88.48, learning rate: 0.0010
# ('epoch : ', 58)
# [19200] , kl_loss 125.74, Word: 81.02, Topo: 98.02, Assm: 95.86 vali_Word: 70.71, vali_Topo: 95.09, vali_assm: 88.41, learning rate: 0.0010
# [19400] , kl_loss 125.33, Word: 80.34, Topo: 97.94, Assm: 95.71 vali_Word: 69.98, vali_Topo: 95.35, vali_assm: 87.40, learning rate: 0.0010
# ('epoch : ', 59)
# [19600] , kl_loss 127.06, Word: 81.43, Topo: 98.06, Assm: 95.96 vali_Word: 71.15, vali_Topo: 95.48, vali_assm: 89.59, learning rate: 0.0010
# ('epoch : ', 60)
# [19800] , kl_loss 123.65, Word: 81.17, Topo: 98.11, Assm: 95.19 vali_Word: 70.59, vali_Topo: 95.14, vali_assm: 88.00, learning rate: 0.0010
# [20000] , kl_loss 111.90, Word: 81.37, Topo: 98.03, Assm: 96.07 vali_Word: 70.68, vali_Topo: 95.22, vali_assm: 88.79, learning rate: 0.0010
# ('epoch : ', 61)
# [20200] , kl_loss 109.18, Word: 81.34, Topo: 98.12, Assm: 95.96 vali_Word: 70.45, vali_Topo: 95.45, vali_assm: 88.41, learning rate: 0.0010
# ('epoch : ', 62)
# [20400] , kl_loss 107.21, Word: 81.79, Topo: 98.09, Assm: 95.70 vali_Word: 71.12, vali_Topo: 95.31, vali_assm: 88.47, learning rate: 0.0010
# [20600] , kl_loss 104.97, Word: 82.26, Topo: 98.27, Assm: 95.96 vali_Word: 70.52, vali_Topo: 95.30, vali_assm: 88.93, learning rate: 0.0010
# ('epoch : ', 63)
# [20800] , kl_loss 102.68, Word: 81.53, Topo: 98.19, Assm: 95.92 vali_Word: 71.23, vali_Topo: 95.25, vali_assm: 89.77, learning rate: 0.0010
# [21000] , kl_loss 102.26, Word: 82.34, Topo: 98.18, Assm: 95.88 vali_Word: 71.01, vali_Topo: 95.33, vali_assm: 88.05, learning rate: 0.0010
# ('epoch : ', 64)
# [21200] , kl_loss 101.47, Word: 82.27, Topo: 98.31, Assm: 96.07 vali_Word: 71.13, vali_Topo: 95.51, vali_assm: 89.03, learning rate: 0.0010
# ('epoch : ', 65)
# [21400] , kl_loss 100.72, Word: 82.50, Topo: 98.33, Assm: 95.81 vali_Word: 70.39, vali_Topo: 95.33, vali_assm: 89.27, learning rate: 0.0010
# [21600] , kl_loss 100.81, Word: 82.62, Topo: 98.26, Assm: 96.23 vali_Word: 70.44, vali_Topo: 95.40, vali_assm: 88.79, learning rate: 0.0010
# ('epoch : ', 66)
# [21800] , kl_loss 98.70, Word: 82.65, Topo: 98.48, Assm: 96.26 vali_Word: 70.22, vali_Topo: 95.33, vali_assm: 88.40, learning rate: 0.0010
# [22000] , kl_loss 97.09, Word: 82.91, Topo: 98.41, Assm: 95.95 vali_Word: 71.35, vali_Topo: 95.60, vali_assm: 89.30, learning rate: 0.0010
# ('epoch : ', 67)
# [22200] , kl_loss 99.07, Word: 83.03, Topo: 98.40, Assm: 96.13 vali_Word: 70.78, vali_Topo: 95.48, vali_assm: 87.97, learning rate: 0.0010
# ('epoch : ', 68)
# [22400] , kl_loss 98.68, Word: 83.14, Topo: 98.37, Assm: 96.41 vali_Word: 70.37, vali_Topo: 95.40, vali_assm: 89.08, learning rate: 0.0010
# [22600] , kl_loss 97.39, Word: 83.31, Topo: 98.29, Assm: 96.29 vali_Word: 70.34, vali_Topo: 95.55, vali_assm: 89.17, learning rate: 0.0010
# ('epoch : ', 69)
# [22800] , kl_loss 96.86, Word: 83.46, Topo: 98.55, Assm: 95.89 vali_Word: 70.72, vali_Topo: 95.33, vali_assm: 88.28, learning rate: 0.0010
# [23000] , kl_loss 97.26, Word: 83.42, Topo: 98.44, Assm: 96.59 vali_Word: 70.92, vali_Topo: 95.16, vali_assm: 88.36, learning rate: 0.0010
# ('epoch : ', 70)
# [23200] , kl_loss 92.69, Word: 83.64, Topo: 98.40, Assm: 96.17 vali_Word: 71.02, vali_Topo: 95.21, vali_assm: 87.95, learning rate: 0.0010
# ('epoch : ', 71)
# [23400] , kl_loss 87.36, Word: 83.60, Topo: 98.59, Assm: 96.03 vali_Word: 70.84, vali_Topo: 95.56, vali_assm: 89.91, learning rate: 0.0010
# [23600] , kl_loss 87.38, Word: 84.09, Topo: 98.41, Assm: 96.35 vali_Word: 70.33, vali_Topo: 95.59, vali_assm: 89.12, learning rate: 0.0010
# ('epoch : ', 72)
# [23800] , kl_loss 86.67, Word: 83.81, Topo: 98.54, Assm: 96.26 vali_Word: 70.84, vali_Topo: 95.80, vali_assm: 89.78, learning rate: 0.0010
# [24000] , kl_loss 86.30, Word: 83.92, Topo: 98.47, Assm: 96.17 vali_Word: 70.47, vali_Topo: 95.28, vali_assm: 88.91, learning rate: 0.0010
# ('epoch : ', 73)
# [24200] , kl_loss 83.69, Word: 84.44, Topo: 98.57, Assm: 96.62 vali_Word: 70.72, vali_Topo: 95.39, vali_assm: 88.92, learning rate: 0.0010
# ('epoch : ', 74)
# [24400] , kl_loss 84.58, Word: 83.77, Topo: 98.52, Assm: 95.33 vali_Word: 71.17, vali_Topo: 95.63, vali_assm: 89.42, learning rate: 0.0010
# [24600] , kl_loss 83.88, Word: 84.28, Topo: 98.53, Assm: 96.26 vali_Word: 70.52, vali_Topo: 95.22, vali_assm: 89.08, learning rate: 0.0010
# ('epoch : ', 75)
# [24800] , kl_loss 83.98, Word: 84.52, Topo: 98.41, Assm: 96.30 vali_Word: 70.57, vali_Topo: 95.41, vali_assm: 88.37, learning rate: 0.0010
# [25000] , kl_loss 82.26, Word: 84.49, Topo: 98.62, Assm: 96.24 vali_Word: 71.30, vali_Topo: 95.60, vali_assm: 89.21, learning rate: 0.0010
# ('epoch : ', 76)
# [25200] , kl_loss 82.55, Word: 84.82, Topo: 98.60, Assm: 97.06 vali_Word: 71.62, vali_Topo: 95.63, vali_assm: 88.17, learning rate: 0.0010
# ('epoch : ', 77)
# [25400] , kl_loss 81.27, Word: 84.27, Topo: 98.69, Assm: 96.28 vali_Word: 70.61, vali_Topo: 95.65, vali_assm: 88.35, learning rate: 0.0010
# [25600] , kl_loss 82.35, Word: 85.06, Topo: 98.56, Assm: 96.17 vali_Word: 70.37, vali_Topo: 95.26, vali_assm: 87.41, learning rate: 0.0010
# ('epoch : ', 78)
# [25800] , kl_loss 81.87, Word: 85.23, Topo: 98.76, Assm: 96.77 vali_Word: 71.69, vali_Topo: 95.44, vali_assm: 89.07, learning rate: 0.0010
# ('epoch : ', 79)
# [26000] , kl_loss 81.32, Word: 84.87, Topo: 98.59, Assm: 96.33 vali_Word: 70.68, vali_Topo: 95.47, vali_assm: 87.94, learning rate: 0.0010
# [26200] , kl_loss 81.59, Word: 85.87, Topo: 98.70, Assm: 96.89 vali_Word: 71.38, vali_Topo: 95.53, vali_assm: 88.93, learning rate: 0.0010
# ('epoch : ', 80)
# [26400] , kl_loss 79.07, Word: 85.25, Topo: 98.60, Assm: 96.30 vali_Word: 70.66, vali_Topo: 95.44, vali_assm: 89.07, learning rate: 0.0010
# [26600] , kl_loss 75.82, Word: 85.22, Topo: 98.60, Assm: 96.48 vali_Word: 70.66, vali_Topo: 95.36, vali_assm: 87.88, learning rate: 0.0010
# ('epoch : ', 81)
# [26800] , kl_loss 75.16, Word: 85.68, Topo: 98.70, Assm: 96.79 vali_Word: 71.12, vali_Topo: 95.33, vali_assm: 88.87, learning rate: 0.0010
# ('epoch : ', 82)
# [27000] , kl_loss 72.81, Word: 85.30, Topo: 98.68, Assm: 96.06 vali_Word: 70.96, vali_Topo: 95.47, vali_assm: 89.45, learning rate: 0.0010
# [27200] , kl_loss 72.87, Word: 85.84, Topo: 98.70, Assm: 96.91 vali_Word: 71.55, vali_Topo: 95.55, vali_assm: 88.90, learning rate: 0.0010
# ('epoch : ', 83)
# [27400] , kl_loss 72.91, Word: 86.12, Topo: 98.77, Assm: 97.24 vali_Word: 71.17, vali_Topo: 95.22, vali_assm: 87.68, learning rate: 0.0010
# [27600] , kl_loss 72.05, Word: 85.58, Topo: 98.58, Assm: 96.28 vali_Word: 70.83, vali_Topo: 95.35, vali_assm: 88.86, learning rate: 0.0010
# ('epoch : ', 84)
# [27800] , kl_loss 72.18, Word: 86.31, Topo: 98.75, Assm: 96.55 vali_Word: 71.47, vali_Topo: 95.40, vali_assm: 87.98, learning rate: 0.0010
# ('epoch : ', 85)
# [28000] , kl_loss 72.00, Word: 85.88, Topo: 98.69, Assm: 96.69 vali_Word: 71.57, vali_Topo: 95.45, vali_assm: 88.42, learning rate: 0.0010
# [28200] , kl_loss 71.34, Word: 86.27, Topo: 98.78, Assm: 96.58 vali_Word: 71.94, vali_Topo: 95.74, vali_assm: 88.73, learning rate: 0.0010
# ('epoch : ', 86)
# [28400] , kl_loss 70.89, Word: 86.56, Topo: 98.77, Assm: 96.36 vali_Word: 71.01, vali_Topo: 95.54, vali_assm: 88.93, learning rate: 0.0010
# [28600] , kl_loss 70.79, Word: 86.23, Topo: 98.68, Assm: 96.58 vali_Word: 69.87, vali_Topo: 95.45, vali_assm: 88.19, learning rate: 0.0010
# ('epoch : ', 87)
# [28800] , kl_loss 71.40, Word: 86.81, Topo: 98.73, Assm: 97.11 vali_Word: 71.29, vali_Topo: 95.33, vali_assm: 89.21, learning rate: 0.0010
# ('epoch : ', 88)
# [29000] , kl_loss 70.02, Word: 85.94, Topo: 98.70, Assm: 96.65 vali_Word: 70.69, vali_Topo: 95.40, vali_assm: 88.52, learning rate: 0.0010
# [29200] , kl_loss 69.98, Word: 86.04, Topo: 98.63, Assm: 96.73 vali_Word: 70.70, vali_Topo: 95.69, vali_assm: 87.56, learning rate: 0.0010
# ('epoch : ', 89)
# [29400] , kl_loss 68.90, Word: 87.01, Topo: 98.79, Assm: 96.66 vali_Word: 70.63, vali_Topo: 95.45, vali_assm: 87.68, learning rate: 0.0010
# [29600] , kl_loss 68.70, Word: 86.04, Topo: 98.70, Assm: 96.32 vali_Word: 71.30, vali_Topo: 95.45, vali_assm: 88.08, learning rate: 0.0010
# ('epoch : ', 90)
# [29800] , kl_loss 66.59, Word: 86.93, Topo: 98.88, Assm: 96.57 vali_Word: 71.12, vali_Topo: 95.50, vali_assm: 88.26, learning rate: 0.0010
# ('epoch : ', 91)
# [30000] , kl_loss 65.11, Word: 87.04, Topo: 98.76, Assm: 96.93 vali_Word: 70.87, vali_Topo: 95.60, vali_assm: 88.90, learning rate: 0.0010
# [30200] , kl_loss 64.22, Word: 87.17, Topo: 98.77, Assm: 96.85 vali_Word: 70.70, vali_Topo: 95.44, vali_assm: 87.88, learning rate: 0.0010
# ('epoch : ', 92)
# [30400] , kl_loss 63.82, Word: 87.23, Topo: 98.92, Assm: 97.01 vali_Word: 70.32, vali_Topo: 95.49, vali_assm: 88.53, learning rate: 0.0010
# ('epoch : ', 93)
# [30600] , kl_loss 63.85, Word: 86.49, Topo: 98.78, Assm: 96.68 vali_Word: 70.13, vali_Topo: 95.39, vali_assm: 88.50, learning rate: 0.0010
# [30800] , kl_loss 63.28, Word: 87.52, Topo: 98.95, Assm: 97.05 vali_Word: 69.99, vali_Topo: 95.42, vali_assm: 88.83, learning rate: 0.0010
# ('epoch : ', 94)
# [31000] , kl_loss 63.82, Word: 87.20, Topo: 98.88, Assm: 96.39 vali_Word: 71.06, vali_Topo: 95.67, vali_assm: 89.11, learning rate: 0.0010
# [31200] , kl_loss 62.90, Word: 87.22, Topo: 98.87, Assm: 96.99 vali_Word: 70.62, vali_Topo: 95.33, vali_assm: 89.33, learning rate: 0.0010
# ('epoch : ', 95)
# [31400] , kl_loss 62.88, Word: 87.61, Topo: 98.80, Assm: 97.23 vali_Word: 71.46, vali_Topo: 95.40, vali_assm: 89.63, learning rate: 0.0010
# ('epoch : ', 96)
# [31600] , kl_loss 62.67, Word: 87.45, Topo: 98.88, Assm: 96.49 vali_Word: 70.63, vali_Topo: 95.31, vali_assm: 89.26, learning rate: 0.0010
# [31800] , kl_loss 62.56, Word: 88.04, Topo: 98.92, Assm: 97.00 vali_Word: 69.83, vali_Topo: 95.45, vali_assm: 88.67, learning rate: 0.0010
# ('epoch : ', 97)
# [32000] , kl_loss 62.42, Word: 87.50, Topo: 98.90, Assm: 96.29 vali_Word: 70.69, vali_Topo: 95.44, vali_assm: 88.76, learning rate: 0.0010
# [32200] , kl_loss 61.48, Word: 87.43, Topo: 98.88, Assm: 96.86 vali_Word: 71.22, vali_Topo: 95.53, vali_assm: 89.49, learning rate: 0.0010
# ('epoch : ', 98)
# [32400] , kl_loss 61.86, Word: 87.88, Topo: 98.94, Assm: 96.94 vali_Word: 71.77, vali_Topo: 95.38, vali_assm: 88.23, learning rate: 0.0010
# ('epoch : ', 99)
# [32600] , kl_loss 61.30, Word: 87.31, Topo: 98.88, Assm: 96.69 vali_Word: 70.90, vali_Topo: 95.39, vali_assm: 89.76, learning rate: 0.0010
# [32800] , kl_loss 61.69, Word: 88.01, Topo: 98.90, Assm: 96.80 vali_Word: 69.36, vali_Topo: 95.47, vali_assm: 88.16, learning rate: 0.0010
# ('epoch : ', 100)
# [33000] , kl_loss 60.39, Word: 87.89, Topo: 98.96, Assm: 96.78 vali_Word: 71.29, vali_Topo: 95.57, vali_assm: 88.66, learning rate: 0.0010
# [33200] , kl_loss 58.36, Word: 87.58, Topo: 98.90, Assm: 96.97 vali_Word: 71.19, vali_Topo: 95.42, vali_assm: 89.37, learning rate: 0.0010
# ('epoch : ', 101)
# [33400] , kl_loss 58.51, Word: 88.18, Topo: 98.96, Assm: 97.02 vali_Word: 70.70, vali_Topo: 95.54, vali_assm: 88.66, learning rate: 0.0010
# ('epoch : ', 102)
# [33600] , kl_loss 57.82, Word: 87.93, Topo: 98.90, Assm: 96.99 vali_Word: 70.79, vali_Topo: 95.46, vali_assm: 89.22, learning rate: 0.0010
# [33800] , kl_loss 57.57, Word: 88.30, Topo: 98.92, Assm: 96.95 vali_Word: 70.13, vali_Topo: 95.42, vali_assm: 88.53, learning rate: 0.0010
# ('epoch : ', 103)
# [34000] , kl_loss 56.76, Word: 88.48, Topo: 98.97, Assm: 96.59 vali_Word: 70.27, vali_Topo: 95.55, vali_assm: 88.44, learning rate: 0.0010
# [34200] , kl_loss 57.47, Word: 88.15, Topo: 99.03, Assm: 96.95 vali_Word: 70.30, vali_Topo: 95.52, vali_assm: 88.27, learning rate: 0.0010
# ('epoch : ', 104)
# [34400] , kl_loss 57.35, Word: 88.50, Topo: 98.97, Assm: 97.17 vali_Word: 70.90, vali_Topo: 95.62, vali_assm: 88.80, learning rate: 0.0010
# ('epoch : ', 105)
# [34600] , kl_loss 57.03, Word: 87.91, Topo: 99.00, Assm: 96.88 vali_Word: 71.06, vali_Topo: 95.32, vali_assm: 88.51, learning rate: 0.0010
# [34800] , kl_loss 56.17, Word: 88.54, Topo: 99.04, Assm: 96.87 vali_Word: 71.24, vali_Topo: 95.58, vali_assm: 88.74, learning rate: 0.0010
# ('epoch : ', 106)
# [35000] , kl_loss 56.32, Word: 88.68, Topo: 98.94, Assm: 97.00 vali_Word: 70.99, vali_Topo: 95.33, vali_assm: 88.76, learning rate: 0.0010
# [35200] , kl_loss 55.38, Word: 88.17, Topo: 99.01, Assm: 97.06 vali_Word: 70.76, vali_Topo: 95.58, vali_assm: 88.02, learning rate: 0.0010
# ('epoch : ', 107)
# [35400] , kl_loss 55.65, Word: 88.71, Topo: 99.05, Assm: 97.17 vali_Word: 70.94, vali_Topo: 95.39, vali_assm: 89.14, learning rate: 0.0010
# ('epoch : ', 108)
# [35600] , kl_loss 55.27, Word: 88.58, Topo: 99.04, Assm: 96.83 vali_Word: 71.73, vali_Topo: 95.52, vali_assm: 88.78, learning rate: 0.0010
# [35800] , kl_loss 55.08, Word: 88.48, Topo: 99.07, Assm: 96.95 vali_Word: 71.04, vali_Topo: 95.45, vali_assm: 88.32, learning rate: 0.0010
# ('epoch : ', 109)
# [36000] , kl_loss 55.23, Word: 88.56, Topo: 99.01, Assm: 96.91 vali_Word: 71.10, vali_Topo: 95.42, vali_assm: 89.24, learning rate: 0.0010
# ('epoch : ', 110)
# [36200] , kl_loss 55.63, Word: 88.56, Topo: 99.00, Assm: 96.95 vali_Word: 71.13, vali_Topo: 95.62, vali_assm: 89.63, learning rate: 0.0010
# [36400] , kl_loss 54.05, Word: 89.03, Topo: 99.04, Assm: 96.71 vali_Word: 70.46, vali_Topo: 95.14, vali_assm: 89.34, learning rate: 0.0010
# ('epoch : ', 111)
# [36600] , kl_loss 52.51, Word: 88.85, Topo: 98.96, Assm: 97.00 vali_Word: 70.40, vali_Topo: 95.45, vali_assm: 89.26, learning rate: 0.0010
# [36800] , kl_loss 52.57, Word: 88.80, Topo: 98.99, Assm: 96.71 vali_Word: 70.76, vali_Topo: 95.73, vali_assm: 89.25, learning rate: 0.0010
# ('epoch : ', 112)
# [37000] , kl_loss 52.14, Word: 89.03, Topo: 99.07, Assm: 97.22 vali_Word: 71.13, vali_Topo: 95.28, vali_assm: 90.41, learning rate: 0.0010
# ('epoch : ', 113)
# [37200] , kl_loss 51.91, Word: 88.71, Topo: 98.99, Assm: 97.22 vali_Word: 71.57, vali_Topo: 95.56, vali_assm: 90.09, learning rate: 0.0010
# [37400] , kl_loss 51.65, Word: 89.23, Topo: 99.07, Assm: 97.01 vali_Word: 71.18, vali_Topo: 95.30, vali_assm: 88.86, learning rate: 0.0010
# ('epoch : ', 114)
# [37600] , kl_loss 51.67, Word: 89.07, Topo: 99.02, Assm: 97.05 vali_Word: 70.40, vali_Topo: 95.48, vali_assm: 89.25, learning rate: 0.0010
# [37800] , kl_loss 52.62, Word: 89.07, Topo: 99.02, Assm: 97.15 vali_Word: 71.85, vali_Topo: 95.44, vali_assm: 88.24, learning rate: 0.0010
# ('epoch : ', 115)
# [38000] , kl_loss 51.52, Word: 89.30, Topo: 99.03, Assm: 97.24 vali_Word: 71.04, vali_Topo: 95.57, vali_assm: 88.36, learning rate: 0.0010
# [41400] , kl_loss 48.32, Word: 89.92, Topo: 99.15, Assm: 97.27 vali_Word: 71.43, vali_Topo: 95.52, vali_assm: 89.22, learning rate: 0.0010
# ('epoch : ', 126)
# [41600] , kl_loss 47.90, Word: 89.88, Topo: 99.17, Assm: 97.40 vali_Word: 71.75, vali_Topo: 95.36, vali_assm: 89.95, learning rate: 0.0010
# ('epoch : ', 127)
# [41800] , kl_loss 47.87, Word: 89.88, Topo: 99.11, Assm: 97.06 vali_Word: 71.20, vali_Topo: 95.40, vali_assm: 89.31, learning rate: 0.0010
# [42000] , kl_loss 48.08, Word: 90.01, Topo: 99.17, Assm: 97.27 vali_Word: 70.63, vali_Topo: 95.39, vali_assm: 88.23, learning rate: 0.0010
# ('epoch : ', 128)
# [42200] , kl_loss 48.13, Word: 90.01, Topo: 99.17, Assm: 96.74 vali_Word: 71.66, vali_Topo: 95.29, vali_assm: 88.97, learning rate: 0.0010
# [42400] , kl_loss 48.34, Word: 90.01, Topo: 99.15, Assm: 97.13 vali_Word: 71.48, vali_Topo: 95.19, vali_assm: 88.87, learning rate: 0.0010
# ('epoch : ', 129)
# [42600] , kl_loss 48.61, Word: 89.80, Topo: 99.13, Assm: 97.22 vali_Word: 70.86, vali_Topo: 95.39, vali_assm: 88.61, learning rate: 0.0010
# ('epoch : ', 130)
# [42800] , kl_loss 48.59, Word: 90.02, Topo: 99.04, Assm: 97.26 vali_Word: 71.43, vali_Topo: 95.29, vali_assm: 88.63, learning rate: 0.0010
# [43000] , kl_loss 46.38, Word: 90.02, Topo: 99.14, Assm: 97.16 vali_Word: 71.34, vali_Topo: 95.44, vali_assm: 89.98, learning rate: 0.0010
# ('epoch : ', 131)
# [43200] , kl_loss 46.20, Word: 90.17, Topo: 99.20, Assm: 97.38 vali_Word: 71.78, vali_Topo: 95.27, vali_assm: 88.71, learning rate: 0.0010
# [43400] , kl_loss 46.40, Word: 89.98, Topo: 99.08, Assm: 97.03 vali_Word: 71.04, vali_Topo: 95.45, vali_assm: 88.77, learning rate: 0.0010
# ('epoch : ', 132)
# [43600] , kl_loss 46.36, Word: 90.41, Topo: 99.13, Assm: 97.33 vali_Word: 70.84, vali_Topo: 95.22, vali_assm: 88.23, learning rate: 0.0010
# ('epoch : ', 133)
# [43800] , kl_loss 46.44, Word: 89.80, Topo: 99.05, Assm: 97.53 vali_Word: 71.31, vali_Topo: 95.31, vali_assm: 89.25, learning rate: 0.0010
# [44000] , kl_loss 45.81, Word: 90.23, Topo: 99.12, Assm: 97.18 vali_Word: 71.80, vali_Topo: 95.46, vali_assm: 89.19, learning rate: 0.0010
# ('epoch : ', 134)
# [44200] , kl_loss 45.79, Word: 90.27, Topo: 99.17, Assm: 97.56 vali_Word: 71.85, vali_Topo: 95.11, vali_assm: 88.10, learning rate: 0.0010
# [44400] , kl_loss 45.56, Word: 89.94, Topo: 99.15, Assm: 96.92 vali_Word: 71.27, vali_Topo: 95.39, vali_assm: 88.58, learning rate: 0.0010
# ('epoch : ', 135)
# [44600] , kl_loss 45.90, Word: 90.51, Topo: 99.16, Assm: 97.42 vali_Word: 71.37, vali_Topo: 95.38, vali_assm: 88.43, learning rate: 0.0010
# ('epoch : ', 136)
# [44800] , kl_loss 45.76, Word: 90.09, Topo: 99.14, Assm: 97.16 vali_Word: 71.51, vali_Topo: 95.23, vali_assm: 89.51, learning rate: 0.0010
# [45000] , kl_loss 45.67, Word: 90.25, Topo: 99.19, Assm: 97.36 vali_Word: 71.48, vali_Topo: 95.41, vali_assm: 88.39, learning rate: 0.0010
# ('epoch : ', 137)
# [45200] , kl_loss 45.56, Word: 90.35, Topo: 99.19, Assm: 97.50 vali_Word: 70.60, vali_Topo: 95.27, vali_assm: 89.12, learning rate: 0.0010
# [45400] , kl_loss 45.55, Word: 90.30, Topo: 99.16, Assm: 97.08 vali_Word: 70.92, vali_Topo: 95.53, vali_assm: 88.95, learning rate: 0.0010
# ('epoch : ', 138)
# [45600] , kl_loss 45.44, Word: 90.71, Topo: 99.20, Assm: 97.26 vali_Word: 71.71, vali_Topo: 95.36, vali_assm: 88.69, learning rate: 0.0010
# ('epoch : ', 139)
# [45800] , kl_loss 45.68, Word: 90.27, Topo: 99.18, Assm: 97.02 vali_Word: 72.14, vali_Topo: 95.70, vali_assm: 89.57, learning rate: 0.0010
# [46000] , kl_loss 45.45, Word: 90.47, Topo: 99.13, Assm: 97.30 vali_Word: 70.49, vali_Topo: 95.47, vali_assm: 88.09, learning rate: 0.0010
# ('epoch : ', 140)
# [46200] , kl_loss 44.59, Word: 90.44, Topo: 99.17, Assm: 97.63 vali_Word: 71.97, vali_Topo: 95.31, vali_assm: 88.22, learning rate: 0.0010
# ('epoch : ', 141)
# [46400] , kl_loss 43.99, Word: 90.30, Topo: 99.14, Assm: 97.58 vali_Word: 71.27, vali_Topo: 95.19, vali_assm: 88.72, learning rate: 0.0010
# [46600] , kl_loss 43.69, Word: 90.62, Topo: 99.21, Assm: 97.62 vali_Word: 71.14, vali_Topo: 95.44, vali_assm: 89.54, learning rate: 0.0010
# ('epoch : ', 142)
# [46800] , kl_loss 43.18, Word: 90.50, Topo: 99.21, Assm: 97.41 vali_Word: 71.56, vali_Topo: 95.50, vali_assm: 89.17, learning rate: 0.0010
# [47000] , kl_loss 43.48, Word: 90.59, Topo: 99.17, Assm: 97.10 vali_Word: 71.81, vali_Topo: 95.40, vali_assm: 89.35, learning rate: 0.0010
# ('epoch : ', 143)
# [47200] , kl_loss 42.99, Word: 90.68, Topo: 99.14, Assm: 97.19 vali_Word: 71.42, vali_Topo: 95.53, vali_assm: 88.68, learning rate: 0.0010
# ('epoch : ', 144)
# [47400] , kl_loss 44.03, Word: 90.23, Topo: 99.21, Assm: 97.29 vali_Word: 71.83, vali_Topo: 95.46, vali_assm: 87.98, learning rate: 0.0010
# [47600] , kl_loss 43.64, Word: 90.72, Topo: 99.26, Assm: 97.14 vali_Word: 71.40, vali_Topo: 95.23, vali_assm: 88.68, learning rate: 0.0010
# ('epoch : ', 145)
# [47800] , kl_loss 43.21, Word: 90.81, Topo: 99.11, Assm: 97.54 vali_Word: 71.39, vali_Topo: 95.26, vali_assm: 88.64, learning rate: 0.0010
# [48000] , kl_loss 43.72, Word: 90.53, Topo: 99.19, Assm: 97.36 vali_Word: 70.56, vali_Topo: 95.24, vali_assm: 89.31, learning rate: 0.0010
# ('epoch : ', 146)
# [48200] , kl_loss 43.36, Word: 91.08, Topo: 99.25, Assm: 97.32 vali_Word: 71.63, vali_Topo: 95.32, vali_assm: 87.74, learning rate: 0.0010
# ('epoch : ', 147)
# [48400] , kl_loss 42.94, Word: 90.89, Topo: 99.17, Assm: 97.31 vali_Word: 71.66, vali_Topo: 95.19, vali_assm: 88.52, learning rate: 0.0010
# [48600] , kl_loss 43.18, Word: 90.68, Topo: 99.25, Assm: 97.60 vali_Word: 70.60, vali_Topo: 95.23, vali_assm: 88.91, learning rate: 0.0010
# ('epoch : ', 148)
# [48800] , kl_loss 43.11, Word: 90.82, Topo: 99.27, Assm: 96.95 vali_Word: 71.55, vali_Topo: 95.17, vali_assm: 88.94, learning rate: 0.0010
# [49000] , kl_loss 42.87, Word: 90.61, Topo: 99.17, Assm: 97.14 vali_Word: 71.16, vali_Topo: 95.36, vali_assm: 88.92, learning rate: 0.0010
# ('epoch : ', 149)
# [49200] , kl_loss 42.92, Word: 90.72, Topo: 99.15, Assm: 97.00 vali_Word: 71.70, vali_Topo: 95.31, vali_assm: 89.11, learning rate: 0.0010
# ('epoch : ', 150)
# [49400] , kl_loss 43.49, Word: 90.59, Topo: 99.14, Assm: 97.39 vali_Word: 71.02, vali_Topo: 95.26, vali_assm: 90.11, learning rate: 0.0010
# [49600] , kl_loss 42.36, Word: 90.73, Topo: 99.16, Assm: 97.33 vali_Word: 70.72, vali_Topo: 95.37, vali_assm: 88.90, learning rate: 0.0010
# ('epoch : ', 151)
# [49800] , kl_loss 41.71, Word: 90.96, Topo: 99.26, Assm: 97.60 vali_Word: 71.63, vali_Topo: 95.25, vali_assm: 88.80, learning rate: 0.0010
# [50000] , kl_loss 41.80, Word: 90.69, Topo: 99.21, Assm: 97.10 vali_Word: 71.54, vali_Topo: 95.35, vali_assm: 89.58, learning rate: 0.0010
# ('epoch : ', 152)
# [50200] , kl_loss 41.66, Word: 91.35, Topo: 99.25, Assm: 97.54 vali_Word: 71.14, vali_Topo: 95.08, vali_assm: 89.26, learning rate: 0.0010
# ('epoch : ', 153)
# [50400] , kl_loss 41.54, Word: 90.66, Topo: 99.17, Assm: 97.58 vali_Word: 71.76, vali_Topo: 95.34, vali_assm: 88.67, learning rate: 0.0010
# [50600] , kl_loss 41.19, Word: 90.73, Topo: 99.22, Assm: 97.47 vali_Word: 70.84, vali_Topo: 95.09, vali_assm: 88.59, learning rate: 0.0010
# ('epoch : ', 154)
# [50800] , kl_loss 41.46, Word: 90.80, Topo: 99.25, Assm: 97.25 vali_Word: 71.21, vali_Topo: 95.28, vali_assm: 88.76, learning rate: 0.0010
# ('epoch : ', 155)
# ('epoch : ', 175)
# [57600] , kl_loss 38.40, Word: 91.31, Topo: 99.28, Assm: 97.15 vali_Word: 71.77, vali_Topo: 95.45, vali_assm: 89.20, learning rate: 0.0010
# [57800] , kl_loss 37.81, Word: 91.73, Topo: 99.34, Assm: 97.66 vali_Word: 71.72, vali_Topo: 95.25, vali_assm: 89.36, learning rate: 0.0010
# ('epoch : ', 176)
# [58000] , kl_loss 38.49, Word: 91.66, Topo: 99.23, Assm: 97.38 vali_Word: 70.79, vali_Topo: 95.25, vali_assm: 89.77, learning rate: 0.0010
# [58200] , kl_loss 38.42, Word: 91.18, Topo: 99.30, Assm: 97.38 vali_Word: 71.46, vali_Topo: 95.41, vali_assm: 89.56, learning rate: 0.0010
# ('epoch : ', 177)
# [58400] , kl_loss 38.40, Word: 91.10, Topo: 99.32, Assm: 97.33 vali_Word: 70.00, vali_Topo: 95.29, vali_assm: 88.72, learning rate: 0.0010
# ('epoch : ', 178)
# [58600] , kl_loss 38.29, Word: 91.43, Topo: 99.28, Assm: 97.37 vali_Word: 70.27, vali_Topo: 95.04, vali_assm: 88.61, learning rate: 0.0010
# [58800] , kl_loss 38.06, Word: 91.59, Topo: 99.25, Assm: 97.54 vali_Word: 71.43, vali_Topo: 95.21, vali_assm: 89.59, learning rate: 0.0010
# ('epoch : ', 179)
# [59000] , kl_loss 38.11, Word: 91.17, Topo: 99.27, Assm: 97.84 vali_Word: 70.91, vali_Topo: 95.39, vali_assm: 87.82, learning rate: 0.0010
# [59200] , kl_loss 38.09, Word: 91.49, Topo: 99.27, Assm: 97.64 vali_Word: 71.18, vali_Topo: 95.12, vali_assm: 89.09, learning rate: 0.0010
# ('epoch : ', 180)
# [59400] , kl_loss 37.55, Word: 91.57, Topo: 99.32, Assm: 97.82 vali_Word: 70.88, vali_Topo: 95.19, vali_assm: 88.94, learning rate: 0.0010
# ('epoch : ', 181)
# [59600] , kl_loss 37.44, Word: 91.03, Topo: 99.21, Assm: 97.32 vali_Word: 71.08, vali_Topo: 95.22, vali_assm: 88.83, learning rate: 0.0010
# [59800] , kl_loss 37.39, Word: 91.30, Topo: 99.26, Assm: 97.61 vali_Word: 71.43, vali_Topo: 95.32, vali_assm: 89.37, learning rate: 0.0010
# ('epoch : ', 182)
# [60000] , kl_loss 37.41, Word: 91.47, Topo: 99.28, Assm: 97.65 vali_Word: 71.96, vali_Topo: 95.17, vali_assm: 88.64, learning rate: 0.0010
# [60200] , kl_loss 37.17, Word: 91.49, Topo: 99.27, Assm: 97.43 vali_Word: 71.20, vali_Topo: 95.24, vali_assm: 89.46, learning rate: 0.0010
# ('epoch : ', 183)
# [60400] , kl_loss 37.01, Word: 91.65, Topo: 99.33, Assm: 97.81 vali_Word: 71.44, vali_Topo: 95.21, vali_assm: 87.95, learning rate: 0.0010
# ('epoch : ', 184)
# [60600] , kl_loss 37.32, Word: 91.72, Topo: 99.18, Assm: 97.29 vali_Word: 71.53, vali_Topo: 95.35, vali_assm: 88.20, learning rate: 0.0010
# [60800] , kl_loss 36.74, Word: 91.49, Topo: 99.23, Assm: 97.12 vali_Word: 71.36, vali_Topo: 95.03, vali_assm: 88.71, learning rate: 0.0010
# ('epoch : ', 185)
# [61000] , kl_loss 36.97, Word: 91.35, Topo: 99.30, Assm: 97.24 vali_Word: 71.49, vali_Topo: 95.18, vali_assm: 89.12, learning rate: 0.0010
# ('epoch : ', 186)
# [61200] , kl_loss 36.86, Word: 91.38, Topo: 99.25, Assm: 97.87 vali_Word: 71.07, vali_Topo: 95.14, vali_assm: 88.94, learning rate: 0.0010
# [61400] , kl_loss 36.84, Word: 91.99, Topo: 99.32, Assm: 97.57 vali_Word: 71.30, vali_Topo: 95.41, vali_assm: 88.67, learning rate: 0.0010
# ('epoch : ', 187)
# [61600] , kl_loss 36.73, Word: 91.86, Topo: 99.31, Assm: 97.55 vali_Word: 70.34, vali_Topo: 95.32, vali_assm: 89.70, learning rate: 0.0010
# [61800] , kl_loss 36.93, Word: 91.68, Topo: 99.32, Assm: 97.37 vali_Word: 71.71, vali_Topo: 95.46, vali_assm: 89.25, learning rate: 0.0010
# ('epoch : ', 188)
# [62000] , kl_loss 36.77, Word: 91.84, Topo: 99.29, Assm: 97.65 vali_Word: 70.85, vali_Topo: 95.42, vali_assm: 88.68, learning rate: 0.0010
# ('epoch : ', 189)
# [62200] , kl_loss 36.89, Word: 91.34, Topo: 99.25, Assm: 97.32 vali_Word: 71.50, vali_Topo: 95.14, vali_assm: 89.10, learning rate: 0.0010
# [62400] , kl_loss 37.00, Word: 91.82, Topo: 99.30, Assm: 97.52 vali_Word: 71.44, vali_Topo: 95.30, vali_assm: 88.29, learning rate: 0.0010
# ('epoch : ', 190)
# [62600] , kl_loss 36.54, Word: 91.71, Topo: 99.30, Assm: 97.28 vali_Word: 71.58, vali_Topo: 95.40, vali_assm: 88.21, learning rate: 0.0010
# [62800] , kl_loss 35.90, Word: 91.57, Topo: 99.31, Assm: 97.47 vali_Word: 71.60, vali_Topo: 95.20, vali_assm: 88.60, learning rate: 0.0010
# ('epoch : ', 191)
# [63000] , kl_loss 36.18, Word: 91.53, Topo: 99.33, Assm: 97.56 vali_Word: 71.10, vali_Topo: 95.26, vali_assm: 89.52, learning rate: 0.0010
# ('epoch : ', 192)
# [63200] , kl_loss 36.27, Word: 91.72, Topo: 99.26, Assm: 97.42 vali_Word: 71.40, vali_Topo: 95.22, vali_assm: 88.43, learning rate: 0.0010
# [63400] , kl_loss 36.09, Word: 91.95, Topo: 99.22, Assm: 97.58 vali_Word: 71.18, vali_Topo: 95.30, vali_assm: 88.60, learning rate: 0.0010
# ('epoch : ', 193)
# [63600] , kl_loss 35.80, Word: 91.84, Topo: 99.24, Assm: 97.25 vali_Word: 71.83, vali_Topo: 95.21, vali_assm: 88.39, learning rate: 0.0010
# [63800] , kl_loss 35.82, Word: 91.54, Topo: 99.29, Assm: 97.54 vali_Word: 71.63, vali_Topo: 95.33, vali_assm: 88.97, learning rate: 0.0010
# ('epoch : ', 194)
# [64000] , kl_loss 35.73, Word: 91.85, Topo: 99.34, Assm: 97.72 vali_Word: 71.60, vali_Topo: 95.41, vali_assm: 89.08, learning rate: 0.0010
# ('epoch : ', 195)
# [64200] , kl_loss 35.91, Word: 91.98, Topo: 99.38, Assm: 97.50 vali_Word: 70.45, vali_Topo: 95.26, vali_assm: 88.53, learning rate: 0.0010
# [64400] , kl_loss 35.90, Word: 91.90, Topo: 99.23, Assm: 97.72 vali_Word: 71.31, vali_Topo: 95.39, vali_assm: 89.82, learning rate: 0.0010
# ('epoch : ', 196)
# [64600] , kl_loss 36.04, Word: 91.67, Topo: 99.37, Assm: 97.74 vali_Word: 71.07, vali_Topo: 95.25, vali_assm: 90.08, learning rate: 0.0010
# [64800] , kl_loss 35.89, Word: 91.42, Topo: 99.22, Assm: 97.42 vali_Word: 71.50, vali_Topo: 95.24, vali_assm: 88.06, learning rate: 0.0010
# ('epoch : ', 197)
# [65000] , kl_loss 35.44, Word: 91.99, Topo: 99.32, Assm: 97.68 vali_Word: 71.06, vali_Topo: 95.25, vali_assm: 89.39, learning rate: 0.0010
# ('epoch : ', 198)
# [65200] , kl_loss 35.58, Word: 91.69, Topo: 99.19, Assm: 97.97 vali_Word: 71.27, vali_Topo: 95.38, vali_assm: 88.90, learning rate: 0.0010
# [65400] , kl_loss 35.82, Word: 91.80, Topo: 99.30, Assm: 97.49 vali_Word: 71.50, vali_Topo: 95.12, vali_assm: 88.34, learning rate: 0.0010
# ('epoch : ', 199)
# [65600] , kl_loss 35.64, Word: 91.97, Topo: 99.24, Assm: 97.55 vali_Word: 70.68, vali_Topo: 95.37, vali_assm: 88.56, learning rate: 0.0010
# [65800] , kl_loss 35.57, Word: 91.21, Topo: 99.25, Assm: 97.46 vali_Word: 71.48, vali_Topo: 95.12, vali_assm: 89.72, learning rate: 0.0010

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit import DataStructs

model_path = "./enc_model/model.iter-65800"
if model_path is not None:
    enc_model.load_state_dict(torch.load(model_path,map_location='cuda'))

model_path = "./dec_model/model.iter-65800"
if model_path is not None:
    dec_model.load_state_dict(torch.load(model_path,map_location='cuda'))

train_dataset.batch_size = 20
vali_dataset.batch_size = 10

sample_rate = 1.0

def evaluation():
    ret = []
    with torch.no_grad():
        for batch in vali_dataset:
            x_batch, x_jtenc_holder, x_mpn_holder, x_jtmpn_holder,x,y = batch
            x = x.to('cuda')
            y = y.to('cuda')
            
            h,_ = enc_model(x,y,training=False,sample=True,sample_rate=sample_rate)
            tree_vec = h[:,:h.shape[1]/2]
            mol_vec  = h[:,h.shape[1]/2:]
            for num in range(h.size()[0]):
                
                true_smiles=x_batch[num].smiles
                predict_smiles = dec_model.decode(tree_vec[num].view(1,latent_size/2),mol_vec[num].view(1,latent_size/2),False)
                
                #smilesの正規化
                true_smiles = Chem.MolToSmiles(Chem.MolFromSmiles(true_smiles),True)
                predict_smiles = Chem.MolToSmiles(Chem.MolFromSmiles(predict_smiles),True)
                
                ret.append((true_smiles,predict_smiles,h[num].data))
    return ret
result = evaluation()
print(len(result))
# Out:
# 730

# %%
import os
from rdkit import Chem
from rdkit.Chem import Draw
from PIL import ImageDraw,ImageFont
from rdkit.Chem import AllChem
from rdkit import DataStructs

from shutil import copyfile
from shutil import make_archive
import zipfile

def _re_smiles(smiles1,smiles2):
    #print(smiles1,smiles2)
    smiles1 = Chem.MolToSmiles(Chem.MolFromSmiles(smiles1),True)
    smiles2 = Chem.MolToSmiles(Chem.MolFromSmiles(smiles2),True)
    return smiles1 == smiles2

def is_structural_isomer(smiles1,smiles2):
    def Molecular_formula(smiles):
        atoms = {}
        mol = Chem.AddHs(Chem.MolFromSmiles(smiles))
        for atom in mol.GetAtoms():
            if not atom.GetSymbol() in atoms:
                atoms[atom.GetSymbol()] = 1
            else:
                atoms[atom.GetSymbol()] += 1
        return atoms
    atoms1 = Molecular_formula(smiles1)
    atoms2 = Molecular_formula(smiles2)
    return atoms1 == atoms2
    
def analyze_result(smiles_list,log_path="evaluation.csv",path="image_list",zipname=None):
    if not os.path.exists(path):
        os.mkdir(path)
    log_path = os.path.join(path,log_path)
    with open(log_path,"w") as f:
        print "Number of data: %d"% (len(smiles_list))
        f.write("Number of data,%d,,\n" % (len(smiles_list)))
        
        match_list = [[i,one[0]] for i,one in enumerate(smiles_list) if _re_smiles(one[0],one[1])]
        print "Number of matching: %d" % (len(match_list))
        f.write("Number of matching,%d,,,\n" % (len(match_list)))
        print(match_list)
    
        isomer_list = [[i,one[0]] for i,one in enumerate(smiles_list) if is_structural_isomer(one[0],one[1]) and [i,one[0]] not in match_list]
        print "Number of matching: %d" % (len(isomer_list))
        f.write("Number of isomer,%d,,,\n" % (len(isomer_list)))
        print(isomer_list)
        
        f.write("true,predict,ECFP-Tanimoto score,MACCS-Tanimoto score\n")
        
    ecfp_score_list = []
    maccs_score_list = []
    for i,smiles in enumerate(smiles_list):
        true_mol = Chem.MolFromSmiles(smiles[0])
        predict_mol = Chem.MolFromSmiles(smiles[1])
        
        true_fingerprint = AllChem.GetMorganFingerprint(true_mol,2)
        predict_fingerprint = AllChem.GetMorganFingerprint(predict_mol,2)
        ECFP_score = DataStructs.TanimotoSimilarity(true_fingerprint,predict_fingerprint)
        
        true_fingerprint = AllChem.GetMACCSKeysFingerprint(true_mol)
        predict_fingerprint = AllChem.GetMACCSKeysFingerprint(predict_mol)
        MACCS_score = DataStructs.TanimotoSimilarity(true_fingerprint,predict_fingerprint)
        
        with open(log_path,"a") as f:
            f.write(smiles[0]+","+smiles[1]+","+str(ECFP_score)+","+str(MACCS_score)+",")
            for num in range(smiles[2].shape[0]):
                f.write(str(smiles[2][num].item()) + ",")
            f.write("\n")
        
        image = Draw.MolsToImage([true_mol,predict_mol])
        draw = ImageDraw.Draw(image)
        font = ImageFont.load_default()
        font.size=40
        draw.text((0,0),str(ECFP_score)+","+str(MACCS_score),(0, 0, 0),font=font)
        image.save(os.path.join(path,"%d.png" % i))
        
    
    copyfile("./log2.csv",os.path.join(path,"log.csv"))
    copyfile("./training.ipynb",os.path.join(path,"Untitled.ipynb"))
    copyfile("./ms_encoder.py",os.path.join(path,"ms_encoder.py"))
)=CC1OC(C)=O'], [511, 'Cc1ccc([N+](=O)[O-])cc1'], [539, 'Cc1c2ccccc2c(COC(=O)C(C)(C)C)c2ccccc12'], [598, 'CC12CCC(CC1=O)C2(C)C'], [610, 'C=C1C(=O)OC2CCCCC(C(C)C)C12'], [643, 'CC(C)CCCC(C)C1CCC2C3CC=C4CC(O[Si](C)(C)C)CCC4(C)C3CCC12C'], [656, 'CCCCCCCCCCCC(=O)OCCCCC'], [695, 'CCOC(=O)C(C)CC'], [716, 'CC(=O)OCOc1ccccc1'], [719, 'CON=C1C=C2CCC3C(CCC4(C)C(C(C)=NOC)CCC34)C2(C)CC1'], [720, 'CC1C=NNC1C']]

# %%
result[0][2].shape
# Out:
# torch.Size([10, 56])

# %%
# !mv evaluation.csv ./result-1.0
# !mv log2.csv ./result-1.0
# !zip -r image.zip ./result-1.0 ./ms_encoder.py ./Untitled.ipynb
# Out:
# updating: image_list/ (stored 0%)
# updating: image_list/471.png (deflated 10%)
# updating: image_list/506.png (deflated 9%)
# updating: image_list/688.png (deflated 7%)
# updating: image_list/231.png (deflated 8%)
# updating: image_list/65.png (deflated 12%)
# updating: image_list/345.png (deflated 8%)
# updating: image_list/598.png (deflated 15%)
# updating: image_list/526.png (deflated 8%)
# updating: image_list/184.png (deflated 6%)
# updating: image_list/196.png (deflated 7%)
# updating: image_list/477.png (deflated 7%)
# updating: image_list/139.png (deflated 16%)
# updating: image_list/430.png (deflated 7%)
# updating: image_list/186.png (deflated 10%)
# updating: image_list/611.png (deflated 12%)
# updating: image_list/265.png (deflated 11%)
# updating: image_list/497.png (deflated 8%)
# updating: image_list/204.png (deflated 12%)
# updating: image_list/464.png (deflated 7%)
# updating: image_list/34.png (deflated 8%)
# updating: image_list/237.png (deflated 7%)
# updating: image_list/665.png (deflated 6%)
# updating: image_list/549.png (deflated 11%)
# updating: image_list/587.png (deflated 9%)
# updating: image_list/281.png (deflated 9%)
# updating: image_list/108.png (deflated 10%)
# updating: image_list/50.png (deflated 8%)
# updating: image_list/571.png (deflated 8%)
# updating: image_list/423.png (deflated 8%)
# updating: image_list/589.png (deflated 8%)
# updating: image_list/516.png (deflated 10%)
# updating: image_list/137.png (deflated 8%)
# updating: image_list/214.png (deflated 12%)
# updating: image_list/428.png (deflated 10%)
# updating: image_list/328.png (deflated 10%)
# updating: image_list/401.png (deflated 16%)
# updating: image_list/708.png (deflated 18%)
# updating: image_list/596.png (deflated 10%)
# updating: image_list/195.png (deflated 13%)
# updating: image_list/277.png (deflated 10%)
# updating: image_list/246.png (deflated 9%)
# updating: image_list/168.png (deflated 16%)
# updating: image_list/282.png (deflated 9%)
# updating: image_list/272.png (deflated 9%)
# updating: image_list/565.png (deflated 6%)
# updating: image_list/461.png (deflated 6%)
# updating: image_list/185.png (deflated 15%)
# updating: image_list/118.png (deflated 8%)
# updating: image_list/233.png (deflated 7%)
# updating: image_list/22.png (deflated 5%)
# updating: image_list/170.png (deflated 11%)
# updating: image_list/643.png (deflated 9%)
# updating: image_list/evaluation.csv (deflated 73%)
# updating: image_list/66.png (deflated 10%)
# updating: image_list/332.png (deflated 8%)
# updating: image_list/692.png (deflated 20%)
# updating: image_list/337.png (deflated 10%)
# updating: image_list/458.png (deflated 7%)
# updating: image_list/96.png (deflated 12%)
# updating: image_list/252.png (deflated 9%)
# updating: image_list/224.png (deflated 10%)
# updating: image_list/358.png (deflated 9%)
# updating: image_list/47.png (deflated 11%)
# updating: image_list/164.png (deflated 18%)
# updating: image_list/149.png (deflated 10%)
# updating: image_list/582.png (deflated 7%)
# updating: image_list/104.png (deflated 9%)
# updating: image_list/169.png (deflated 12%)
# updating: image_list/81.png (deflated 9%)
# updating: image_list/619.png (deflated 9%)
# updating: image_list/336.png (deflated 16%)
# updating: image_list/512.png (deflated 12%)
# updating: image_list/77.png (deflated 8%)
# updating: image_list/91.png (deflated 11%)
# updating: image_list/574.png (deflated 8%)
# updating: image_list/530.png (deflated 8%)
# updating: image_list/664.png (deflated 7%)
# updating: image_list/517.png (deflated 8%)
# updating: image_list/286.png (deflated 14%)
# updating: image_list/369.png (deflated 8%)
# updating: image_list/21.png (deflated 6%)
# updating: image_list/171.png (deflated 8%)
# updating: image_list/674.png (deflated 4%)
# updating: image_list/487.png (deflated 5%)
# updating: image_list/150.png (deflated 10%)
# updating: image_list/529.png (deflated 8%)
# updating: image_list/562.png (deflated 10%)
# updating: image_list/568.png (deflated 7%)
# updating: image_list/467.png (deflated 6%)
# updating: image_list/583.png (deflated 11%)
# updating: image_list/402.png (deflated 10%)
# updating: image_list/176.png (deflated 13%)
# updating: image_list/482.png (deflated 8%)
# updating: image_list/635.png (deflated 10%)
# updating: image_list/348.png (deflated 14%)
# updating: image_list/475.png (deflated 9%)
# updating: image_list/146.png (deflated 7%)
# updating: image_list/527.png (deflated 10%)
# updating: image_list/351.png (deflated 9%)
# updating: image_list/236.png (deflated 10%)
# updating: image_list/40.png (deflated 7%)
# updating: image_list/283.png (deflated 9%)
# updating: image_list/537.png (deflated 12%)
# updating: image_list/153.png (deflated 7%)
# updating: image_list/312.png (deflated 13%)
# updating: image_list/490.png (deflated 8%)
# updating: image_list/625.png (deflated 5%)
# updating: image_list/394.png (deflated 7%)
# updating: image_list/268.png (deflated 9%)
# updating: image_list/206.png (deflated 7%)
# updating: image_list/373.png (deflated 16%)
# updating: image_list/8.png (deflated 8%)
# updating: image_list/133.png (deflated 15%)
# updating: image_list/3.png (deflated 8%)
# updating: image_list/717.png (deflated 7%)
# updating: image_list/343.png (deflated 9%)
# updating: image_list/418.png (deflated 8%)
# updating: image_list/log2.csv (deflated 63%)
# updating: ms_encoder.py (deflated 83%)
# updating: Untitled.ipynb (deflated 82%)
#   adding: image_list/.ipynb_checkpoints/ (stored 0%)
#   adding: image_list/.ipynb_checkpoints/124-checkpoint.png (deflated 13%)
#   adding: image_list/.ipynb_checkpoints/evaluation-checkpoint.csv (deflated 81%)

# %%
with open("test_vali_data.pkl","wb") as f:
    pickle.dump(vali_dataset,f)

# %%
with open("test_vali_data.pkl","rb") as f:
    vali_dataset = pickle.load(f)
